# %% [markdown]
# For Loop
# Task 1:
# A lab keeps records of resistor values. Students need to print each resistance value for verification.
# Print each resistance value from a list of resistors.
# 	Create a list, then use for loop to display each item.

# %%
resistors = [100, 220, 470, 1000, 2200]

for resistance in resistors:
    print(f"Resistance: {resistance} Ω")
# Out:
# Resistance: 100 Ω
# Resistance: 220 Ω
# Resistance: 470 Ω
# Resistance: 1000 Ω
# Resistance: 2200 Ω

# %% [markdown]
# Task 2:
# Current readings are stored in a list. Engineers want to calculate the square of each value for power loss calculation.
# Print the square of each current reading using formula I².
# 	Make a list of current values, loop and multiply each by itself.

# %%
currents = [1.5, 2.3, 0.8, 3.1, 1.9]

for current in currents:
    square = current * current
    print(f"Current: {current} A, I²: {square:.2f} A²")
# Out:
# Current: 1.5 A, I²: 2.25 A²
# Current: 2.3 A, I²: 5.29 A²
# Current: 0.8 A, I²: 0.64 A²
# Current: 3.1 A, I²: 9.61 A²
# Current: 1.9 A, I²: 3.61 A²

# %% [markdown]
# Task 3:
# Instruments in a lab are labelled by serial numbers. Students want to auto-generate these numbers.
# Print serial numbers from 1 to 10 for lab instruments.
# 	Use range(1, 11) in for loop.

# %%
for serial in range(1, 11):
    print(f"Instrument Serial: {serial:03d}")
# Out:
# Instrument Serial: 001
# Instrument Serial: 002
# Instrument Serial: 003
# Instrument Serial: 004
# Instrument Serial: 005
# Instrument Serial: 006
# Instrument Serial: 007
# Instrument Serial: 008
# Instrument Serial: 009
# Instrument Serial: 010

# %% [markdown]
# Task 4:
# A power company records voltage values at different times of the day. Students must print all these values for analysis.
# Print each voltage value from a list of voltages

# %%
voltages = [220.5, 215.2, 230.1, 210.8, 225.3]

print("Voltage Readings:")
for voltage in voltages:
    print(f"{voltage} V")
# Out:
# Voltage Readings:
# 220.5 V
# 215.2 V
# 230.1 V
# 210.8 V
# 225.3 V

# %% [markdown]
# Task 5:
#             A lab has capacitor values stored in microfarads. Students need to calculate and print double of each value (since two are connected in parallel).
# Print double of each capacitor value from a list.

# %%
capacitors = [10, 22, 47, 100, 220]

for cap in capacitors:
    double = cap * 2
    print(f"Capacitor: {cap} µF, Double (parallel): {double} µF")
# Out:
# Capacitor: 10 µF, Double (parallel): 20 µF
# Capacitor: 22 µF, Double (parallel): 44 µF
# Capacitor: 47 µF, Double (parallel): 94 µF
# Capacitor: 100 µF, Double (parallel): 200 µF
# Capacitor: 220 µF, Double (parallel): 440 µF

# %% [markdown]
# Task 6:
#             A lab records temperature readings from 5 different sensors. Students must display each sensor’s temperature one by one.
# Print all sensor temperatures from a list.

# %%
temperatures = [23.5, 25.1, 22.8, 24.3, 21.9]

for i, temp in enumerate(temperatures, 1):
    print(f"Sensor {i}: {temp}°C")
# Out:
# Sensor 1: 23.5°C
# Sensor 2: 25.1°C
# Sensor 3: 22.8°C
# Sensor 4: 24.3°C
# Sensor 5: 21.9°C

# %% [markdown]
# Task 7:
#              A solar system records daily energy in kWh. Students must calculate and print half of each value (to simulate half-load usage).
# Print half of each solar energy reading from a list.

# %%
energy_readings = [4.5, 5.2, 3.8, 4.9, 5.5]

for energy in energy_readings:
    half_energy = energy / 2
    print(f"Energy: {energy} kWh, Half-load: {half_energy:.1f} kWh")
# Out:
# Energy: 4.5 kWh, Half-load: 2.2 kWh
# Energy: 5.2 kWh, Half-load: 2.6 kWh
# Energy: 3.8 kWh, Half-load: 1.9 kWh
# Energy: 4.9 kWh, Half-load: 2.5 kWh
# Energy: 5.5 kWh, Half-load: 2.8 kWh

# %% [markdown]
# While Loop
# Task 1:
# During charging, the battery slowly increases its percentage. Students want to simulate this charging process in code.
# Keep printing "Charging..." until battery percentage reaches 100%.
# 	Start with battery = 0, increase by 10 in each loop, stop when 100.

# %%
battery = 0

while battery < 100:
    print(f"Charging... {battery}%")
    battery += 10

print("Battery fully charged: 100%")
# Out:
# Charging... 0%
# Charging... 10%
# Charging... 20%
# Charging... 30%
# Charging... 40%
# Charging... 50%
# Charging... 60%
# Charging... 70%
# Charging... 80%
# Charging... 90%
# Battery fully charged: 100%

# %% [markdown]
# Task 2:
# Engineers use countdown timers for testing. Students must simulate a timer that runs before starting a test.
# Countdown timer from 10 to 0, showing "Test Running".
# 	Start variable = 10, decrease each loop, stop at 0.

# %%
timer = 10

while timer > 0:
    print(f"Countdown: {timer}")
    timer -= 1

print("Test Running")
# Out:
# Countdown: 10
# Countdown: 9
# Countdown: 8
# Countdown: 7
# Countdown: 6
# Countdown: 5
# Countdown: 4
# Countdown: 3
# Countdown: 2
# Countdown: 1
# Test Running

# %% [markdown]
# Task 3:
# A voltage monitoring system asks for user input repeatedly until the system is turned off.
# Keep asking user for voltage until they enter 0.
# 	Use input() in while loop, stop when entered value is 0.

# %%
while True:
    voltage_input = input("Enter voltage (0 to stop): ")
    voltage = float(voltage_input)
    
    if voltage == 0:
        break
    
    print(f"Recorded voltage: {voltage} V")

print("Monitoring stopped")
# Out:
# Recorded voltage: 5.0 V
# Recorded voltage: 5.0 V
# Monitoring stopped

# %% [markdown]
# Task 4:
# Power in a system doubles when load increases. Students need to simulate this doubling until it reaches a limit.
# Keep doubling the power until it exceeds 1000 W.
# 	Start power = 1, multiply by 2 each loop, stop when >1000.

# %%
power = 1

while power <= 1000:
    print(f"Current power: {power} W")
    power = power * 2

print(f"Power exceeded 1000 W: {power} W")
# Out:
# Current power: 1 W
# Current power: 2 W
# Current power: 4 W
# Current power: 8 W
# Current power: 16 W
# Current power: 32 W
# Current power: 64 W
# Current power: 128 W
# Current power: 256 W
# Current power: 512 W
# Power exceeded 1000 W: 1024 W

# %% [markdown]
# Task 5:
#             A machine keeps running until its cycle count reaches a limit. Students must simulate this with a loop.
# Start from cycle = 1 and keep printing "Cycle Running" until cycle reaches 5.

# %%
cycle = 1

while cycle <= 5:
    print(f"Cycle {cycle}: Cycle Running")
    cycle += 1

print("All cycles completed")
# Out:
# Cycle 1: Cycle Running
# Cycle 2: Cycle Running
# Cycle 3: Cycle Running
# Cycle 4: Cycle Running
# Cycle 5: Cycle Running
# All cycles completed

# %% [markdown]
# Task 6:
#             A motor runs until its speed reaches 3000 RPM. Students must simulate this by starting from 0 and adding 500 each loop.
# Keep increasing speed by 500 until it reaches 3000, printing the speed each time.

# %%
speed = 0

while speed < 3000:
    print(f"Motor speed: {speed} RPM")
    speed += 500

print(f"Target speed reached: {speed} RPM")
# Out:
# Motor speed: 0 RPM
# Motor speed: 500 RPM
# Motor speed: 1000 RPM
# Motor speed: 1500 RPM
# Motor speed: 2000 RPM
# Motor speed: 2500 RPM
# Target speed reached: 3000 RPM
