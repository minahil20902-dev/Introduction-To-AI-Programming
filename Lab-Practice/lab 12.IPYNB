# %% [markdown]
# Lab Practice Task:
# In the below task first run the code then understand the error and fix the code with exception handling.
# Task 1: Type Error (Add int and string)
# Step 1: Run This Code
# a = 10
# b = "5"
# result = a + b
# print(result)
# What Happens:
# The program crashes due to incompatible data types(Understand the error).
# Step 2: Fix the Code
# Modify the code so the error is handled properly and a clear message is displayed instead of a crash
# Use the Following Concepts
# 	try
# 	except
# 	TypeError

# %%
try:
    a = 10
    b = "5"
    result = a + b
    print(result)
except TypeError as e:
    print(f"TypeError: Cannot add integer and string. Details: {e}")
    print("Please ensure both operands are of compatible types.")
# Out:
# TypeError: Cannot add integer and string. Details: unsupported operand type(s) for +: 'int' and 'str'
# Please ensure both operands are of compatible types.

# %% [markdown]
# Task 2: Division by Zero
# Step 1: Run This Code
# x = 20
# y = 0
# result = x / y
# print(result)
# What Happens
# The program terminates due to division by zero(Understand the error).
# Handle the exception and display a meaningful error message.
# Use the Following Concepts
# 	try
# 	except
# 	ZeroDivisionError

# %%
try:
    x = 20
    y = 0
    result = x / y
    print(result)
except ZeroDivisionError as e:
    print(f"ZeroDivisionError: Cannot divide by zero. Details: {e}")
    print("Please provide a non-zero divisor.")
# Out:
# ZeroDivisionError: Cannot divide by zero. Details: division by zero
# Please provide a non-zero divisor.

# %% [markdown]
# Task 3: List Index Out of Range
# Step 1: Run This Code
# numbers = [10, 20, 30]
# print(numbers[5])
# What Happens
# The program crashes due to invalid index access.
# Step 2: Fix the Code
# Catch the exception and display a message indicating the index is invalid.
# Use the Following Concepts
# 	try
# 	except
# 	IndexError

# %%
try:
    numbers = [10, 20, 30]
    print(numbers[5])
except IndexError as e:
    print(f"IndexError: Invalid list index. Details: {e}")
    print(f"List has {len(numbers)} elements, valid indices are 0 to {len(numbers)-1}")
# Out:
# IndexError: Invalid list index. Details: list index out of range
# List has 3 elements, valid indices are 0 to 2

# %% [markdown]
# Task 4: Logical Error Using raise
# Step 1: Run This Code
# age = -5
# print("Age:", age)
#
# What Happens
# The program runs, but the data is logically incorrect.
# Step 2: Fix the Code
# Modify the program to detect the invalid value and raise an exception manually.
# Use the Following Concepts
# 	raise
# 	Exception

# %%
age = -5

try:
    if age < 0:
        raise ValueError("Age cannot be negative")
    print("Age:", age)
except ValueError as e:
    print(f"ValueError: {e}")
# Out:
# ValueError: Age cannot be negative

# %% [markdown]
# Task 5: Assert Failure
# Step 1: Run This Code
# total_marks = 0
# assert total_marks > 0
# print("Total marks:", total_marks)
#
# What Happens
# The program stops due to a failed assertion.
# Step 2: Fix the Code
# Correct the condition or handle the assertion failure properly.
# Use the Following Concepts
# •	assert
# •	AssertionError

# %%
total_marks = 0

try:
    assert total_marks > 0, "Total marks must be greater than 0"
    print("Total marks:", total_marks)
except AssertionError as e:
    print(f"AssertionError: {e}")
    print("Please check the total marks value.")
# Out:
# AssertionError: Total marks must be greater than 0
# Please check the total marks value.

# %% [markdown]
# Task 6: Assert Failure
#
# try:
#     x = int("2")
# except ValueError:
#     print("Error")
# else:
#     print("No error occurred")
# finally:
#     print("Always executed")
#
# Run this code and understand by changing the code.

# %%
try:
    x = int("2")
except ValueError:
    print("Error")
else:
    print("No error occurred")
finally:
    print("Always executed")
# Out:
# No error occurred
# Always executed
