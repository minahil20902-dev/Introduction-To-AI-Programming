# %% [markdown]
# Lab Report Task:
# You are developing a simple energy consumption logging system for a residential building.
# Daily electricity usage is stored in a CSV file. so it can be easily read, updated, and organized.
#
# Task 1: Create and Write Energy Data to a CSV File
# Create a file named energy_data.csv.
# Write the header and daily energy consumption records into the file using the CSV format:
# 	Date
# 	Energy consumed in kWh
# Each record must be written on a new line following the header.
#
# Task 2: Read and Display CSV File Data
# Read the contents of energy_data.csv and display all energy consumption records in a clear and readable format.
# The data must be read from the file, not hardcoded.
#
# Task 3: Append New Energy Records
# Add new daily energy consumption records to energy_data.csv without removing existing data.
# Ensure:
# 	The CSV format is preserved
# 	New data is appended correctly

# %%
import csv

# Task 1: Create and write energy data
with open("energy_data.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Date", "Energy_kWh"])
    writer.writerow(["2025-12-30", 12.5])
    writer.writerow(["2025-12-31", 15.2])
    writer.writerow(["2026-01-01", 13.8])

# Task 2: Read and display CSV file
print("Existing Energy Records:")
with open("energy_data.csv", mode="r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)

# Task 3: Append new records
new_records = [
    ["2026-01-02", 14.1],
    ["2026-01-03", 16.0]
]

with open("energy_data.csv", mode="a", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(new_records)

# Display updated data
print("\nUpdated Energy Records:")
with open("energy_data.csv", mode="r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# Existing Energy Records:
# ['Date', 'Energy_kWh']
# ['2025-12-30', '12.5']
# ['2025-12-31', '15.2']
# ['2026-01-01', '13.8']
#
# Updated Energy Records:
# ['Date', 'Energy_kWh']
# ['2025-12-30', '12.5']
# ['2025-12-31', '15.2']
# ['2026-01-01', '13.8']
# ['2026-01-02', '14.1']
# ['2026-01-03', '16.0']
