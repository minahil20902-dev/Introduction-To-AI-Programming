# %% [markdown]
# Lab Report Tasks:

# %% [markdown]
# You are working in a university electronics lab.
# You are asked to monitor a small solar home system installed on the lab roof. The system has:
# a)	A solar panel
# b)	A battery
# c)	A load controller
# d)	A temperature sensor
# Each minute, the system sends a small dictionary of readings
# I.	Create a dictionary named reading1 containing the 5 fields shown in the scenario.
# II.	From reading1, print:
# i.	The solar power
# ii.	The battery voltage
# iii.	The load status
# III.	Print how many fields the dictionary contains after your modifications.
# IV.	Remove the "panel_current" field.
# V.	Get Keys, Values, and Items
# Print:
# i.	All keys
# ii.	All values
# iii.	All key-value pairs
# iv.	Use .keys(), .values(), and .items().

# %%
reading1 = {
    "panel_voltage": 18.5,
    "panel_current": 2.3,
    "battery_voltage": 12.6,
    "load_status": "ON",
    "temperature": 35
}

print("Solar Panel Voltage:", reading1["panel_voltage"])
print("Battery Voltage:", reading1["battery_voltage"])
print("Load Status:", reading1["load_status"])

print("Number of fields:", len(reading1))

reading1.pop("panel_current")

print("Number of fields after removal:", len(reading1))

print("Keys:", reading1.keys())
print("Values:", reading1.values())
print("Items:", reading1.items())
# Out:
# Solar Panel Voltage: 18.5
# Battery Voltage: 12.6
# Load Status: ON
# Number of fields: 5
# Number of fields after removal: 4
# Keys: dict_keys(['panel_voltage', 'battery_voltage', 'load_status', 'temperature'])
# Values: dict_values([18.5, 12.6, 'ON', 35])
# Items: dict_items([('panel_voltage', 18.5), ('battery_voltage', 12.6), ('load_status', 'ON'), ('temperature', 35)])
