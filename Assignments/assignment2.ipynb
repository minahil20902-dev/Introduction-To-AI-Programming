# %%
import csv
print("\n\n=== ASSIGNMENT 2 ===")


days = []
hours = []
consumptions = []


with open('consumption_data.csv', 'r') as file:
    reader = csv.reader(file)
    next(reader) 
    
    for row in reader:
        day = int(row[0])      
        hour = int(row[1])      
        consumption = float(row[2])
        
        days.append(day)
        hours.append(hour)
        consumptions.append(consumption)

print("Data loaded successfully!")
print(f"Days: {days}")
print(f"Hours: {hours}")
print(f"Consumptions: {consumptions}")


hour_groups = {}


for i in range(len(hours)):
    current_hour = hours[i]
    current_consumption = consumptions[i]
    
    
    if current_hour not in hour_groups:
        hour_groups[current_hour] = []
    
    
    hour_groups[current_hour].append(current_consumption)

print("\n--- HOURLY GROUPING ---")
for hour in sorted(hour_groups.keys()):
    print(f"Hour {hour}: {hour_groups[hour]}")
    
    
    total_for_hour = 0
    for value in hour_groups[hour]:
        total_for_hour = total_for_hour + value
    
    average_for_hour = total_for_hour / len(hour_groups[hour])
    
    peak_for_hour = hour_groups[hour][0]
    for value in hour_groups[hour]:
        if value > peak_for_hour:
            peak_for_hour = value
    
    print(f"  Average: {average_for_hour:.2f}")
    print(f"  Peak: {peak_for_hour}")

day_groups = {}

for i in range(len(days)):
    current_day = days[i]
    current_consumption = consumptions[i]
    

    if current_day not in day_groups:
        day_groups[current_day] = []
    
    day_groups[current_day].append(current_consumption)

print("\n--- DAILY GROUPING ---")
for day in sorted(day_groups.keys()):
    print(f"Day {day}: {day_groups[day]}")
    
    
    total_for_day = 0
    for value in day_groups[day]:
        total_for_day = total_for_day + value
    
    
    average_for_day = total_for_day / len(day_groups[day])
    
    print(f"  Total: {total_for_day}")
    print(f"  Average: {average_for_day:.2f}")
# Out:
# === ASSIGNMENT 2 ===
# Data loaded successfully!
# Days: [7, 7, 7, 7, 7, 7, 8, 8, 8, 8, 8, 8, 9, 9, 9, 9, 9, 9, 10, 10, 10, 10, 10, 10]
# Hours: [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]
# Consumptions: [200.0, 300.0, 500.0, 700.0, 600.0, 400.0, 800.0, 700.0, 600.0, 500.0, 400.0, 650.0, 200.0, 300.0, 400.0, 500.0, 600.0, 300.0, 700.0, 800.0, 900.0, 600.0, 500.0, 400.0]
#
# --- HOURLY GROUPING ---
# Hour 1: [200.0, 800.0, 200.0, 700.0]
#   Average: 475.00
#   Peak: 800.0
# Hour 2: [300.0, 700.0, 300.0, 800.0]
#   Average: 525.00
#   Peak: 800.0
# Hour 3: [500.0, 600.0, 400.0, 900.0]
#   Average: 600.00
#   Peak: 900.0
# Hour 4: [700.0, 500.0, 500.0, 600.0]
#   Average: 575.00
#   Peak: 700.0
# Hour 5: [600.0, 400.0, 600.0, 500.0]
#   Average: 525.00
#   Peak: 600.0
# Hour 6: [400.0, 650.0, 300.0, 400.0]
#   Average: 437.50
#   Peak: 650.0
#
# --- DAILY GROUPING ---
# Day 7: [200.0, 300.0, 500.0, 700.0, 600.0, 400.0]
#   Total: 2700.0
#   Average: 450.00
# ...
